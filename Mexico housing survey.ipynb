# %% [markdown]
# # MEXICO HOUSING PROJECT

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv(r"C:\Users\user\Desktop\HR-Employee-Attrition.csv")
df.info()
df.shape
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
from matplotlib import pyplot as plt

df.dropna()
plt.hist(df['Department'])
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Histogram');

# %%
import pandas as pd

data = {
    "price_approx_usd": [115910.26, 48718.17, 28977.56, 36932.27, 83903.51],
    "surface_covered_in_m2": [128.0, 210.0, 58.0, 79.0, 111.0],
    "rooms": [4.0, 3.0, 2.0, 3.0, 3.0],
}

data_frame = pd.DataFrame(data)
print(data_frame)
data_frame.head()
# Out:
#    price_approx_usd  surface_covered_in_m2  rooms
# 0         115910.26                  128.0    4.0
# 1          48718.17                  210.0    3.0
# 2          28977.56                   58.0    2.0
# 3          36932.27                   79.0    3.0
# 4          83903.51                  111.0    3.0
#    price_approx_usd  surface_covered_in_m2  rooms
# 0         115910.26                  128.0    4.0
# 1          48718.17                  210.0    3.0
# 2          28977.56                   58.0    2.0
# 3          36932.27                   79.0    3.0
# 4          83903.51                  111.0    3.0

# %%
house_0_dict = {
    "price_approx_usd": 115910.26,
    "surface_covered_in_m2": 128,
    "rooms": 4,
}
new_price = house_0_dict["price_approx_usd"] / house_0_dict["surface_covered_in_m2"]
print(new_price)
house_0_dict['new_price'] = house_0_dict["price_approx_usd"] / house_0_dict["surface_covered_in_m2"]
print(house_0_dict)
# Out:
# 905.54890625
# {'price_approx_usd': 115910.26, 'surface_covered_in_m2': 128, 'rooms': 4, 'new_price': 905.54890625}

# %%
# Declare variable `houses_rowwise`
houses_rowwise = [
    {
        "price_approx_usd": 115910.26,
        "surface_covered_in_m2": 128,
        "rooms": 4,
    },
    {
        "price_approx_usd": 48718.17,
        "surface_covered_in_m2": 210,
        "rooms": 3,
    },
    {
        "price_approx_usd": 28977.56,
        "surface_covered_in_m2": 58,
        "rooms": 2,
    },
    {
        "price_approx_usd": 36932.27,
        "surface_covered_in_m2": 79,
        "rooms": 3,
    },
    {
        "price_approx_usd": 83903.51,
        "surface_covered_in_m2": 111,
        "rooms": 3,
    },
]
for houses in houses_rowwise:
    print(houses)
    houses['newest_price'] = houses["price_approx_usd"] / houses["surface_covered_in_m2"]    
print(houses_rowwise)
# Out:
# {'price_approx_usd': 115910.26, 'surface_covered_in_m2': 128, 'rooms': 4}
# {'price_approx_usd': 48718.17, 'surface_covered_in_m2': 210, 'rooms': 3}
# {'price_approx_usd': 28977.56, 'surface_covered_in_m2': 58, 'rooms': 2}
# {'price_approx_usd': 36932.27, 'surface_covered_in_m2': 79, 'rooms': 3}
# {'price_approx_usd': 83903.51, 'surface_covered_in_m2': 111, 'rooms': 3}
# [{'price_approx_usd': 115910.26, 'surface_covered_in_m2': 128, 'rooms': 4, 'newest_price': 905.54890625}, {'price_approx_usd': 48718.17, 'surface_covered_in_m2': 210, 'rooms': 3, 'newest_price': 231.9912857142857}, {'price_approx_usd': 28977.56, 'surface_covered_in_m2': 58, 'rooms': 2, 'newest_price': 499.61310344827587}, {'price_approx_usd': 36932.27, 'surface_covered_in_m2': 79, 'rooms': 3, 'newest_price': 467.4970886075949}, {'price_approx_usd': 83903.51, 'surface_covered_in_m2': 111, 'rooms': 3, 'newest_price': 755.8874774774774}]

# %%
house_price = []
for house in houses_rowwise:
    house['price_approx_usd']
    house_price.append(house['price_approx_usd'])

print(house_price)
print(sum(house_price))
print(len(house_price))
mean_price = sum(house_price) / len(house_price)
print(mean_price)
# Out:
# [115910.26, 48718.17, 28977.56, 36932.27, 83903.51]
# 314441.76999999996
# 5
# 62888.35399999999

# %%
houses_columnwise = {
    "price_approx_usd": [115910.26, 48718.17, 28977.56, 36932.27, 83903.51],
    "surface_covered_in_m2": [128.0, 210.0, 58.0, 79.0, 111.0],
    "rooms": [4.0, 3.0, 2.0, 3.0, 3.0],
}

print(houses_columnwise['price_approx_usd'])
print(sum(houses_columnwise['price_approx_usd']) / len(houses_columnwise['price_approx_usd']))
print(sum(houses_columnwise['price_approx_usd']))
print(len(houses_columnwise['price_approx_usd']))
# Out:
# [115910.26, 48718.17, 28977.56, 36932.27, 83903.51]
# 62888.35399999999
# 314441.76999999996
# 5

# %%
houses_columnwise = {
    "price_approx_usd": [115910.26, 48718.17, 28977.56, 36932.27, 83903.51],
    "surface_covered_in_m2": [128.0, 210.0, 58.0, 79.0, 111.0],
    "rooms": [4.0, 3.0, 2.0, 3.0, 3.0],
}

price = houses_columnwise['price_approx_usd']
area = houses_columnwise['surface_covered_in_m2']
print(list(zip(price, area)))

price_per_m2 = []
for p, a in zip(price, area):
    print('price:', p)
    print('area:', a)
    price_m2 = p / a
    print(price_m2)
    price_per_m2.append(price_m2)
    
print(price_per_m2)
houses_columnwise['price_per_m2'] = price_per_m2
print(houses_columnwise)
# Out:
# [(115910.26, 128.0), (48718.17, 210.0), (28977.56, 58.0), (36932.27, 79.0), (83903.51, 111.0)]
# price: 115910.26
# area: 128.0
# 905.54890625
# price: 48718.17
# area: 210.0
# 231.9912857142857
# price: 28977.56
# area: 58.0
# 499.61310344827587
# price: 36932.27
# area: 79.0
# 467.4970886075949
# price: 83903.51
# area: 111.0
# 755.8874774774774
# [905.54890625, 231.9912857142857, 499.61310344827587, 467.4970886075949, 755.8874774774774]
# {'price_approx_usd': [115910.26, 48718.17, 28977.56, 36932.27, 83903.51], 'surface_covered_in_m2': [128.0, 210.0, 58.0, 79.0, 111.0], 'rooms': [4.0, 3.0, 2.0, 3.0, 3.0], 'price_per_m2': [905.54890625, 231.9912857142857, 499.61310344827587, 467.4970886075949, 755.8874774774774]}

# %%
# World Quant University Housing Project

houses_nested_list = [
    [115910.26, 128.0, 4.0],
    [48718.17, 210.0, 3.0],
    [28977.56, 58.0, 2.0],
    [36932.27, 79.0, 3.0],
    [83903.51, 111.0, 3.0],
]

for houses in houses_nested_list:
    print(houses)
    price = houses[0] / houses[1]
    houses.append(price)
    
print(houses_nested_list)
# Out:
# [115910.26, 128.0, 4.0]
# [48718.17, 210.0, 3.0]
# [28977.56, 58.0, 2.0]
# [36932.27, 79.0, 3.0]
# [83903.51, 111.0, 3.0]
# [[115910.26, 128.0, 4.0, 905.54890625], [48718.17, 210.0, 3.0, 231.9912857142857], [28977.56, 58.0, 2.0, 499.61310344827587], [36932.27, 79.0, 3.0, 467.4970886075949], [83903.51, 111.0, 3.0, 755.8874774774774]]
